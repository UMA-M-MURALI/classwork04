# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading
df = pd.read_excel(r"C:\Users\Administrator\Downloads\Telco-Customer-Churn.xlsx")
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
 #1comparing data
df["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df_Churn=sns.countplot(df["gender"],hue=df["Churn"])
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#2number of female citizens
df["SeniorCitizen"].value_counts()
# Out:
# 0.0    5901
# 1.0    1142
# Name: SeniorCitizen, dtype: int64

# %%
data_femalecitizen = sns.countplot(data=df, x = "SeniorCitizen",hue = "gender")
plt.title("senior citizen vs female", fontsize=16, color="Blue")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#comparing tenure with total charges
plt.figure(figsize=(8,8))
plt.title("Tenure vs total charges")
sns.scatterplot(x="tenure" , y = "TotalCharges" , data = df)
plt.show()

# %%
#contact preferred by senior citizen
plt.figure()
df_Contract= sns.countplot(x = "SeniorCitizen",data = df, hue = "Contract")
plt.title("SeniorCitizen preferred contact", size = 14 ,color="Pink")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#findings on payment
plt.figure()
df_payment= sns.countplot(x="gender", data = df,hue = "PaymentMethod")
plt.title("Payment based on gender")
plt.show()

# %%
#
plt.figure()
df_payment= sns.countplot(x="SeniorCitizen", data = df,hue = "PaymentMethod")
plt.title("Payment based on Citizen")
plt.show()
